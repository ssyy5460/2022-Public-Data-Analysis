# %%
import pandas as pd

# %%
borough = pd.read_csv("최종_구_선정_기준.csv", encoding = "euc-kr")

# %%
borough.head(10)
# Out:
#   시군구명  어린이집수  국공립/민간비율  보육교사수  보육교사 1인당 아동수  전체 충족률      일반출생률   신혼부부  \
# 0  강남구    189     57.89   1720           4.4   70.11  16.194610   9267
# 1  강동구    242     81.13   2034           5.2   80.69  22.545157  11801
# 2  강북구    128     88.24   1046           5.3   76.32  15.798312   5442
# 3  강서구    322    123.61   2397           4.9   77.96  22.257192  15457
# 4  관악구    192     52.11   1425           4.9   74.21  14.445224   9955
# 5  광진구    154     71.77   1165           4.7   76.47  16.485615   7605
# 6  구로구    270     67.50   1885           5.1   78.74  23.843426  10988
# 7  금천구    135     79.44   1078           4.8   70.19  20.448481   5380
# 8  노원구    324     71.43   1988           4.3   77.25  18.231718  10304
# 9  도봉구    174     80.00   1238           4.8   75.23  17.341287   6042
#
#    보육시설 아동비율
# 0   0.586880
# 1   0.702055
# 2   0.894523
# 3   0.712563
# 4   0.761010
# 5   0.701358
# 6   0.784270
# 7   0.939339
# 8   0.670778
# 9   0.799621

# %%
borough_minmax = pd.read_csv("최종_구_선정_기준_min_max.csv", encoding = "euc-kr")

# %%
borough_minmax.head(10)
# Out:
#   시군구명     어린이집수  국공립.민간비율     보육교사수  보육교사.1인당.아동수    전체.충족률     일반출생률  \
# 0  강남구  0.450185  0.208193  0.462040      0.307692  0.222885  0.144672
# 1  강동구  0.645756  0.488193  0.608291      0.923077  0.796638  0.669853
# 2  강북구  0.225092  0.573855  0.148114      1.000000  0.559653  0.111899
# 3  강서구  0.940959  1.000000  0.777364      0.692308  0.648590  0.646039
# 4  관악구  0.461255  0.138554  0.324639      0.692308  0.445228  0.000000
# 5  광진구  0.321033  0.375422  0.203540      0.538462  0.567787  0.168738
# 6  구로구  0.749077  0.323976  0.538891      0.846154  0.690889  0.777218
# 7  금천구  0.250923  0.467831  0.163018      0.615385  0.227223  0.496461
# 8  노원구  0.948339  0.371325  0.586865      0.230769  0.610087  0.313138
# 9  도봉구  0.394834  0.474578  0.237541      0.615385  0.500542  0.239500
#
#        신혼부부  보육시설.아동비율
# 0  0.483327   0.000000
# 1  0.665041   0.258807
# 2  0.209035   0.691298
# 3  0.927214   0.282419
# 4  0.532664   0.391284
# 5  0.364145   0.257241
# ...
